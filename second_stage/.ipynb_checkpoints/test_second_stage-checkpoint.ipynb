# %%
import glob
import csv
import tqdm
import copy
import numpy as np
import pandas as pd
import catboost
import math

# %%
pd.set_option('display.max_columns', 800)

# %% [markdown]
# # Load track features into dataframe

# %%
track_features_dir = "/media/data2/Data/wsdm2019/data/track_features/"
track_feature_files = sorted(glob.glob(track_features_dir+"*.csv"))
track_feature_dir_0 = track_feature_files[0]
track_feature_0 = pd.read_csv(track_feature_dir_0)

track_feature_dir_1 = track_feature_files[1]
track_feature_1 = pd.read_csv(track_feature_dir_1)

track_feature_all = track_feature_0.append(track_feature_1)

# %%
# get this so that it's easier to merge with train indexes
track_feature_id_index = track_feature_all.set_index('track_id')

# %% [markdown]
# # Load session features into dataframe

# %%
train_set_dir = "/media/data2/Data/wsdm2019/data/training_set/"
second_stage_file_dir = "/media/data2/Data/wsdm2019/python/data/second_stage/"

train_files = sorted(glob.glob(train_set_dir+"*.csv"))

catboost_files = train_files[500:]

temp_catboost_train_file_size = 4
temp_catboost_valid_file_size = 1

catboost_train_files = catboost_files[:temp_catboost_train_file_size][0:1]
catboost_valid_files = catboost_files[temp_catboost_train_file_size:temp_catboost_valid_file_size + temp_catboost_train_file_size]

# %%
train_df_list = []
valid_df_list = []

for f in catboost_train_files:
    s_f = second_stage_file_dir + f[45:-4] + "_second_stage.csv"
    df_raw = pd.read_csv(f).rename(index=str, columns={"track_id_clean": "track_id"})
    df_f = pd.read_csv(s_f)
    df_raw['logits'] = df_f.iloc[:,0].values
    train_df_list.append(df_raw)    

for f in catboost_valid_files:
    s_f = second_stage_file_dir + f[45:-4] + "_second_stage.csv"
    df_raw = pd.read_csv(f).rename(index=str, columns={"track_id_clean": "track_id"})
    df_f = pd.read_csv(s_f)
    df_raw['logits'] = df_f.iloc[:,0].values
    valid_df_list.append(df_raw)
    
catboost_train_raw = pd.concat(train_df_list, ignore_index=True)
catboost_valid_raw = pd.concat(valid_df_list, ignore_index=True)

# %%
catboost_train_raw_group = catboost_train_raw.groupby('session_id')
ngroups = catboost_train_raw_group.ngroups

# %%
print(ngroups)
# Out:
# 940033

# %%
session_dropped_columns = ['session_id', 'track_id', 'session_position']
session_bool_columns = ['skip_1', 'skip_2', 'skip_3', 'not_skipped', 'context_switch', 'no_pause_before_play', 'short_pause_before_play',
                'long_pause_before_play', 'hist_user_behavior_is_shuffle', 'premium']
session_numerical_columns = ['hist_user_behavior_n_seekfwd', 'hist_user_behavior_n_seekback']
session_numerical_columns_range_map = {'hist_user_behavior_n_seekfwd': (0,100), 'hist_user_behavior_n_seekback': (0,100)}
session_categorical_columns = ['context_type', 'hist_user_behavior_reason_start', 'hist_user_behavior_reason_end', 'session_length', 'hour_of_day', 'date']

# %%
track_dropped_columns = ['track_id']
track_numerical_columns = ['duration', 'us_popularity_estimate', 'acousticness', 'beat_strength', 'bounciness', 'danceability',
                             'dyn_range_mean', 'energy', 'flatness', 'instrumentalness', 'liveness', 'loudness', 'mechanism', 
                             'organism', 'speechiness', 'tempo', 'valence']
track_vector_columns = ['acoustic_vector_0', 'acoustic_vector_1', 'acoustic_vector_2', 
                        'acoustic_vector_3', 'acoustic_vector_4', 'acoustic_vector_5',
                        'acoustic_vector_6', 'acoustic_vector_7']
track_categorical_columns = ['release_year', 'key', 'mode', 'time_signature']

# %%
# def get_session_history_summarization(test_group_history):
#     num_feature_list = []
#     cat_feature_list = []
#     for feature in test_group_history.columns:
#         if feature in history_bool_columns:
#             col = test_group_history[feature].astype(int)
#             num_feature_list.extend([col.mean(), col.var(), col.mode()[0]])
#         elif feature in history_numerical_columns:
#             (mi, ma) = history_numerical_columns_range_map[feature]
#             col = test_group_history[feature].clip(mi, ma)
#             col = (col - mi) / (ma - mi)
#             num_feature_list.extend([col.mean(), col.var()])
#         elif feature in history_categorical_columns:
#             col = test_group_history[feature]
#             cat_feature_list.append(col.mode()[0])
#     return num_feature_list, cat_feature_list
def get_session_history_summarization(test_group_history):
    num_feature_list = []
    cat_feature_list = []
    
    for feature in test_group_history.columns:
        if feature in numerical_columns:
            (mi, ma) = history_numerical_columns_range_map[feature]
            col = test_group_history[feature].clip(mi, ma)
            col = (col - mi) / (ma - mi)
            num_feature_list.extend([col.mean(), col.var()])
    
    bool_cols = test_group_history[history_bool_columns].astype(int)
    num_feature_list.extend(bool_cols.mean().tolist())
    num_feature_list.extend(bool_cols.var().tolist())
    num_feature_list.extend(bool_cols.mode().iloc[0].tolist())
    
    cat_cols = test_group_history[history_categorical_columns]
    
    cat_feature_list.extend(cat_cols.mode().iloc[0].astype(str).tolist())
    
    return num_feature_list, cat_feature_list

# %%
def get_track_df(track_list):
    return track_feature_id_index.loc[track_list]

# %%
def get_current_track_feature(self_track_df):
    num_feature_list = []
    cat_feature_list = []
#     for feature in self_track_df.columns:
#         print(feature)
#     if feature in predict_numerical_columns:
    num_feature_list.extend(self_track_df[predict_numerical_columns].tolist())
    cat_feature_list.extend(self_track_df[predict_categorical_columns].astype(str).tolist())
    return num_feature_list, cat_feature_list

# %%
def get_tracks_df_summarization_feature(tracks_df):
    num_feature_list = []
    cat_feature_list = []
    
    num_feature_list.extend(tracks_df[track_numerical_columns].mean().tolist())
#     num_feature_list.extend(tracks_df[track_numerical_columns].var().tolist())
    num_feature_list.extend(tracks_df[track_numerical_columns].min().tolist())
    num_feature_list.extend(tracks_df[track_numerical_columns].max().tolist())
    
    cat_feature_list.extend(tracks_df[track_categorical_columns].mode().iloc[0].astype(str).tolist())
    
    return num_feature_list, cat_feature_list

# %%
num_feat_train = []
cat_feat_train = []
target_train = []

# %%
counter = 0

num_feat_train = []
cat_feat_train = []
target_train = []

for name, test_group in catboost_train_raw_group:
    
    test_group_history = test_group.iloc[:math.floor(test_group['session_position'].size / 2)].rename(index=str, columns={"track_id_clean": "track_id"})
    test_group_predict_all = test_group.iloc[math.floor(test_group['session_position'].size / 2):].rename(index=str, columns={"track_id_clean": "track_id"})
    test_group_predict = test_group_predict_all.iloc[:,:4]
    test_group_predict['logits'] = test_group_predict_all['logits']
    test_group_target = test_group_predict_all.iloc[:, 5].astype(int)

    target_train.extend(test_group_target.tolist())

    # first get the summarization data
    num_feat_hist, cat_feat_hist = get_session_history_summarization(test_group_history)

    # use the append of two piecese because of the structure of test set
    all_track_ids = test_group_history['track_id'].append(test_group_predict['track_id'])

    # used to fill in 0s if it's the last song in the current history since it don't have after tracks
    num_feat_after_sum_len = 51
    cat_feat_after_sum_len = 4

    isLast = False
    for index, row in test_group_predict.iterrows():
        num_feat_predict_row = []
        cat_feat_predict_row = []

        num_feat_predict_row.extend(num_feat_hist)
        cat_feat_predict_row.extend(cat_feat_hist)

        # add categorical variable session_position (session length is already included in cat_feat_hist)
        session_position = row[1]
        cat_feat_predict_row.append(session_position)

        # use the append of two piecese because of the structure of test set
        entire_track_id = test_group_history['track_id'].append(test_group_predict['track_id'])

        before_tracks = all_track_ids[:(session_position - 1)]
        current_track = all_track_ids[(session_position - 1)]
        after_tracks = all_track_ids[(session_position):]
        if (len(after_tracks) == 0):
            isLast = True

        # count of how many times this item have appeared before and after current track
        before_count = (before_tracks == current_track).sum() / len(before_tracks)
        before_proportion = before_count / len(before_tracks)
        if isLast:
            after_count = 0
            after_proportion = 0
        else:
            after_count = (after_tracks == current_track).sum() / len(after_tracks)
            after_proportion = after_count / len(after_tracks)
        num_feat_predict_row.extend([after_count, after_proportion, before_count, before_proportion])

        # get the three corresponding dataframes
        current_track_df = get_track_df(current_track)
        before_tracks_df = get_track_df(before_tracks)
        after_tracks_df = get_track_df(after_tracks)

        # get current track data
        num_feat_current, cat_feat_current = get_current_track_feature(current_track_df)
        num_feat_predict_row.extend(num_feat_current)
        cat_feat_predict_row.extend(cat_feat_current)

        # get before tracks summarization data
        num_feat_before_sum, cat_feat_before_sum = get_tracks_df_summarization_feature(before_tracks_df)
        num_feat_predict_row.extend(num_feat_before_sum)
        cat_feat_predict_row.extend(cat_feat_before_sum)

        # get after tracks summarizaiton data
        if isLast:
            num_feat_after_sum = [0] * num_feat_after_sum_len
            cat_feat_after_sum = ['last'] * cat_feat_after_sum_len
        else:
            num_feat_after_sum, cat_feat_after_sum = get_tracks_df_summarization_feature(after_tracks_df)

        num_feat_predict_row.extend(num_feat_after_sum)
        cat_feat_predict_row.extend(cat_feat_after_sum)

        # add numerical feature logits
        logit = row[4]
        num_feat_predict_row.append(logit)

        num_feat_train.append(num_feat_predict_row)
        cat_feat_train.append(cat_feat_predict_row)
        
    counter += 1
    if counter % 100 == 0:
        print(counter)
        
    if counter == 1000:
        break
# Out:
# 100
# 200
# 300
# 400
# 500
# 600
# 700
# 800
# 900
# 1000

# %%
len(num_feat_train)
# Out:
# 8334

# %%
len(cat_feat_train)
# Out:
# 8334

# %%
len(target_train)
# Out:
# 8334

# %%
num_feat_valid = num_feat_train[-1000:]
cat_feat_valid = cat_feat_train[-1000:]
target_valid = target_train[-1000:]

# %%
n_train = num_feat_train[:-1000]
c_train = cat_feat_train[:-1000]
t = target_train[:-1000]

# %%
train = [a+b for a,b in zip(c_train, n_train)]
valid = [a+b for a,b in zip(cat_feat_valid, num_feat_valid)]

# %%
from catboost import CatBoostClassifier, Pool
p = Pool(train, t, list(range(19)))

# %%
cb_model = CatBoostClassifier(iterations=500,
                              eval_metric='AUC',
                              learning_rate=0.1,
                              objective='Precision'
                              max_depth=15)

# %%
cb_model.fit(p)
# Out:
# 0:	learn: 0.6876328	total: 98.5ms	remaining: 49.1s
# 1:	learn: 0.6825583	total: 191ms	remaining: 47.5s
# 2:	learn: 0.6783092	total: 271ms	remaining: 44.9s
# 3:	learn: 0.6737668	total: 360ms	remaining: 44.6s
# 4:	learn: 0.6686857	total: 448ms	remaining: 44.3s
# 5:	learn: 0.6640080	total: 522ms	remaining: 43s
# 6:	learn: 0.6593562	total: 603ms	remaining: 42.5s
# 7:	learn: 0.6551011	total: 677ms	remaining: 41.6s
# 8:	learn: 0.6503446	total: 761ms	remaining: 41.5s
# 9:	learn: 0.6458050	total: 846ms	remaining: 41.4s
# 10:	learn: 0.6419549	total: 934ms	remaining: 41.5s
# 11:	learn: 0.6386669	total: 1.02s	remaining: 41.5s
# 12:	learn: 0.6355102	total: 1.09s	remaining: 40.9s
# 13:	learn: 0.6318590	total: 1.18s	remaining: 41s
# 14:	learn: 0.6287358	total: 1.26s	remaining: 40.9s
# 15:	learn: 0.6255940	total: 1.35s	remaining: 40.7s
# 16:	learn: 0.6226129	total: 1.43s	remaining: 40.5s
# 17:	learn: 0.6207163	total: 1.47s	remaining: 39.5s
# 18:	learn: 0.6175146	total: 1.55s	remaining: 39.3s
# 19:	learn: 0.6147962	total: 1.64s	remaining: 39.4s
# 20:	learn: 0.6122565	total: 1.72s	remaining: 39.3s
# 21:	learn: 0.6095771	total: 1.83s	remaining: 39.8s
# 22:	learn: 0.6069181	total: 1.92s	remaining: 39.9s
# 23:	learn: 0.6053072	total: 1.97s	remaining: 39.1s
# 24:	learn: 0.6030963	total: 2.05s	remaining: 39s
# 25:	learn: 0.6008020	total: 2.14s	remaining: 39.1s
# 26:	learn: 0.5985680	total: 2.22s	remaining: 38.9s
# 27:	learn: 0.5972954	total: 2.26s	remaining: 38.1s
# 28:	learn: 0.5951890	total: 2.34s	remaining: 38s
# 29:	learn: 0.5927498	total: 2.42s	remaining: 37.9s
# 30:	learn: 0.5913405	total: 2.51s	remaining: 37.9s
# 31:	learn: 0.5902346	total: 2.55s	remaining: 37.3s
# 32:	learn: 0.5886240	total: 2.62s	remaining: 37.1s
# 33:	learn: 0.5868652	total: 2.7s	remaining: 37.1s
# 34:	learn: 0.5856117	total: 2.78s	remaining: 37s
# 35:	learn: 0.5838028	total: 2.86s	remaining: 36.8s
# 36:	learn: 0.5824729	total: 2.88s	remaining: 36.1s
# 37:	learn: 0.5816090	total: 2.92s	remaining: 35.5s
# 38:	learn: 0.5805819	total: 2.99s	remaining: 35.3s
# 39:	learn: 0.5786979	total: 3.07s	remaining: 35.3s
# 40:	learn: 0.5768256	total: 3.15s	remaining: 35.3s
# 41:	learn: 0.5754655	total: 3.23s	remaining: 35.2s
# 42:	learn: 0.5743152	total: 3.29s	remaining: 35s
# 43:	learn: 0.5730119	total: 3.37s	remaining: 35s
# 44:	learn: 0.5721821	total: 3.45s	remaining: 34.9s
# 45:	learn: 0.5712842	total: 3.53s	remaining: 34.9s
# 46:	learn: 0.5706367	total: 3.57s	remaining: 34.4s
# 47:	learn: 0.5695637	total: 3.65s	remaining: 34.3s
# 48:	learn: 0.5686801	total: 3.71s	remaining: 34.1s
# 49:	learn: 0.5676119	total: 3.78s	remaining: 34s
# 50:	learn: 0.5670848	total: 3.82s	remaining: 33.6s
# 51:	learn: 0.5660093	total: 3.9s	remaining: 33.6s
# 52:	learn: 0.5648102	total: 3.98s	remaining: 33.6s
# 53:	learn: 0.5639354	total: 4.06s	remaining: 33.5s
# 54:	learn: 0.5632871	total: 4.13s	remaining: 33.5s
# 55:	learn: 0.5625335	total: 4.22s	remaining: 33.5s
# 56:	learn: 0.5616769	total: 4.32s	remaining: 33.6s
# 57:	learn: 0.5612381	total: 4.36s	remaining: 33.2s
# 58:	learn: 0.5606072	total: 4.47s	remaining: 33.4s
# 59:	learn: 0.5599132	total: 4.57s	remaining: 33.5s
# 60:	learn: 0.5588131	total: 4.68s	remaining: 33.7s
# 61:	learn: 0.5580770	total: 4.78s	remaining: 33.7s
# 62:	learn: 0.5572950	total: 4.86s	remaining: 33.7s
# 63:	learn: 0.5562778	total: 4.95s	remaining: 33.7s
# 64:	learn: 0.5559698	total: 4.99s	remaining: 33.4s
# 65:	learn: 0.5553641	total: 5.08s	remaining: 33.4s
# 66:	learn: 0.5547471	total: 5.16s	remaining: 33.4s
# 67:	learn: 0.5542436	total: 5.25s	remaining: 33.3s
# 68:	learn: 0.5534127	total: 5.33s	remaining: 33.3s
# 69:	learn: 0.5528408	total: 5.41s	remaining: 33.3s
# 70:	learn: 0.5519700	total: 5.49s	remaining: 33.2s
# 71:	learn: 0.5509736	total: 5.58s	remaining: 33.1s
# 72:	learn: 0.5503095	total: 5.65s	remaining: 33s
# 73:	learn: 0.5497044	total: 5.73s	remaining: 33s
# 74:	learn: 0.5494040	total: 5.79s	remaining: 32.8s
# 75:	learn: 0.5491672	total: 5.83s	remaining: 32.5s
# 76:	learn: 0.5487522	total: 5.92s	remaining: 32.5s
# 77:	learn: 0.5479606	total: 6s	remaining: 32.5s
# 78:	learn: 0.5471932	total: 6.09s	remaining: 32.5s
# 79:	learn: 0.5466977	total: 6.17s	remaining: 32.4s
# 80:	learn: 0.5462623	total: 6.26s	remaining: 32.4s
# 81:	learn: 0.5456991	total: 6.35s	remaining: 32.4s
# 82:	learn: 0.5449745	total: 6.43s	remaining: 32.3s
# 83:	learn: 0.5443122	total: 6.51s	remaining: 32.2s
# 84:	learn: 0.5437324	total: 6.59s	remaining: 32.2s
# 85:	learn: 0.5433104	total: 6.67s	remaining: 32.1s
# 86:	learn: 0.5427545	total: 6.76s	remaining: 32.1s
# 87:	learn: 0.5425528	total: 6.8s	remaining: 31.8s
# 88:	learn: 0.5418434	total: 6.88s	remaining: 31.8s
# 89:	learn: 0.5413942	total: 6.97s	remaining: 31.8s
# 90:	learn: 0.5408758	total: 7.05s	remaining: 31.7s
# 91:	learn: 0.5404353	total: 7.13s	remaining: 31.6s
# 92:	learn: 0.5401321	total: 7.2s	remaining: 31.5s
# 93:	learn: 0.5396545	total: 7.27s	remaining: 31.4s
# 94:	learn: 0.5393066	total: 7.36s	remaining: 31.4s
# 95:	learn: 0.5390557	total: 7.44s	remaining: 31.3s
# 96:	learn: 0.5387422	total: 7.51s	remaining: 31.2s
# 97:	learn: 0.5381938	total: 7.59s	remaining: 31.1s
# 98:	learn: 0.5379516	total: 7.63s	remaining: 30.9s
# 99:	learn: 0.5378628	total: 7.67s	remaining: 30.7s
# 100:	learn: 0.5374381	total: 7.76s	remaining: 30.6s
# 101:	learn: 0.5371385	total: 7.83s	remaining: 30.6s
# 102:	learn: 0.5366048	total: 7.92s	remaining: 30.5s
# 103:	learn: 0.5362255	total: 8s	remaining: 30.5s
# 104:	learn: 0.5357621	total: 8.07s	remaining: 30.4s
# 105:	learn: 0.5354802	total: 8.16s	remaining: 30.3s
# 106:	learn: 0.5351410	total: 8.24s	remaining: 30.3s
# 107:	learn: 0.5350486	total: 8.28s	remaining: 30s
# 108:	learn: 0.5348440	total: 8.33s	remaining: 29.9s
# 109:	learn: 0.5345034	total: 8.41s	remaining: 29.8s
# 110:	learn: 0.5341013	total: 8.49s	remaining: 29.8s
# 111:	learn: 0.5336044	total: 8.57s	remaining: 29.7s
# 112:	learn: 0.5332551	total: 8.65s	remaining: 29.6s
# 113:	learn: 0.5328906	total: 8.74s	remaining: 29.6s
# 114:	learn: 0.5325073	total: 8.82s	remaining: 29.5s
# 115:	learn: 0.5322567	total: 8.9s	remaining: 29.5s
# 116:	learn: 0.5321022	total: 8.97s	remaining: 29.4s
# 117:	learn: 0.5319825	total: 9.03s	remaining: 29.2s
# 118:	learn: 0.5318838	total: 9.11s	remaining: 29.2s
# 119:	learn: 0.5312178	total: 9.19s	remaining: 29.1s
# 120:	learn: 0.5308629	total: 9.28s	remaining: 29.1s
# 121:	learn: 0.5305673	total: 9.36s	remaining: 29s
# 122:	learn: 0.5304555	total: 9.41s	remaining: 28.8s
# 123:	learn: 0.5301564	total: 9.49s	remaining: 28.8s
# 124:	learn: 0.5298709	total: 9.57s	remaining: 28.7s
# 125:	learn: 0.5292639	total: 9.65s	remaining: 28.7s
# 126:	learn: 0.5291148	total: 9.7s	remaining: 28.5s
# 127:	learn: 0.5289492	total: 9.76s	remaining: 28.4s
# 128:	learn: 0.5286341	total: 9.84s	remaining: 28.3s
# 129:	learn: 0.5283033	total: 9.92s	remaining: 28.2s
# 130:	learn: 0.5282250	total: 9.96s	remaining: 28.1s
# 131:	learn: 0.5278721	total: 10.1s	remaining: 28s
# 132:	learn: 0.5276403	total: 10.1s	remaining: 27.9s
# 133:	learn: 0.5273661	total: 10.2s	remaining: 27.9s
# 134:	learn: 0.5269616	total: 10.3s	remaining: 27.8s
# 135:	learn: 0.5266879	total: 10.4s	remaining: 27.8s
# 136:	learn: 0.5265001	total: 10.5s	remaining: 27.8s
# 137:	learn: 0.5261436	total: 10.6s	remaining: 27.8s
# 138:	learn: 0.5258087	total: 10.7s	remaining: 27.7s
# 139:	learn: 0.5255377	total: 10.7s	remaining: 27.6s
# 140:	learn: 0.5250029	total: 10.8s	remaining: 27.5s
# 141:	learn: 0.5245621	total: 10.9s	remaining: 27.5s
# 142:	learn: 0.5241929	total: 11s	remaining: 27.5s
# 143:	learn: 0.5239263	total: 11.1s	remaining: 27.4s
# 144:	learn: 0.5237549	total: 11.2s	remaining: 27.3s
# 145:	learn: 0.5236184	total: 11.2s	remaining: 27.2s
# 146:	learn: 0.5235659	total: 11.3s	remaining: 27s
# 147:	learn: 0.5233239	total: 11.3s	remaining: 26.9s
# 148:	learn: 0.5230042	total: 11.4s	remaining: 26.8s
# 149:	learn: 0.5226022	total: 11.5s	remaining: 26.8s
# 150:	learn: 0.5223322	total: 11.5s	remaining: 26.7s
# 151:	learn: 0.5220229	total: 11.6s	remaining: 26.6s
# 152:	learn: 0.5218687	total: 11.7s	remaining: 26.6s
# 153:	learn: 0.5217342	total: 11.8s	remaining: 26.5s
# 154:	learn: 0.5215083	total: 11.9s	remaining: 26.4s
# 155:	learn: 0.5214073	total: 12s	remaining: 26.4s
# 156:	learn: 0.5212594	total: 12s	remaining: 26.3s
# 157:	learn: 0.5210838	total: 12.1s	remaining: 26.2s
# 158:	learn: 0.5210439	total: 12.2s	remaining: 26.1s
# 159:	learn: 0.5207785	total: 12.2s	remaining: 26s
# 160:	learn: 0.5204707	total: 12.3s	remaining: 25.9s
# 161:	learn: 0.5200070	total: 12.4s	remaining: 25.8s
# 162:	learn: 0.5198093	total: 12.5s	remaining: 25.8s
# 163:	learn: 0.5194441	total: 12.6s	remaining: 25.7s
# 164:	learn: 0.5191754	total: 12.6s	remaining: 25.7s
# 165:	learn: 0.5189463	total: 12.7s	remaining: 25.6s
# 166:	learn: 0.5187639	total: 12.8s	remaining: 25.5s
# 167:	learn: 0.5186183	total: 12.9s	remaining: 25.5s
# 168:	learn: 0.5184354	total: 13s	remaining: 25.4s
# 169:	learn: 0.5183245	total: 13.1s	remaining: 25.3s
# 170:	learn: 0.5182705	total: 13.1s	remaining: 25.2s
# 171:	learn: 0.5181755	total: 13.2s	remaining: 25.1s
# 172:	learn: 0.5179894	total: 13.2s	remaining: 25s
# 173:	learn: 0.5178431	total: 13.3s	remaining: 25s
# 174:	learn: 0.5175348	total: 13.4s	remaining: 24.9s
# 175:	learn: 0.5169646	total: 13.5s	remaining: 24.8s
# 176:	learn: 0.5167867	total: 13.6s	remaining: 24.8s
# 177:	learn: 0.5166780	total: 13.7s	remaining: 24.7s
# 178:	learn: 0.5165917	total: 13.8s	remaining: 24.7s
# 179:	learn: 0.5165772	total: 13.8s	remaining: 24.5s
# 180:	learn: 0.5163533	total: 13.9s	remaining: 24.5s
# 181:	learn: 0.5162291	total: 14s	remaining: 24.4s
# 182:	learn: 0.5158455	total: 14s	remaining: 24.3s
# 183:	learn: 0.5156479	total: 14.1s	remaining: 24.2s
# 184:	learn: 0.5155700	total: 14.2s	remaining: 24.2s
# 185:	learn: 0.5155331	total: 14.2s	remaining: 24s
# 186:	learn: 0.5153131	total: 14.3s	remaining: 24s
# 187:	learn: 0.5151843	total: 14.4s	remaining: 23.9s
# 188:	learn: 0.5148423	total: 14.5s	remaining: 23.9s
# 189:	learn: 0.5146097	total: 14.6s	remaining: 23.8s
# 190:	learn: 0.5144282	total: 14.7s	remaining: 23.8s
# 191:	learn: 0.5140816	total: 14.8s	remaining: 23.7s
# 192:	learn: 0.5138153	total: 14.9s	remaining: 23.6s
# 193:	learn: 0.5136175	total: 14.9s	remaining: 23.6s
# 194:	learn: 0.5130890	total: 15s	remaining: 23.5s
# 195:	learn: 0.5129151	total: 15.1s	remaining: 23.4s
# 196:	learn: 0.5124783	total: 15.2s	remaining: 23.4s
# 197:	learn: 0.5121161	total: 15.3s	remaining: 23.3s
# 198:	learn: 0.5120250	total: 15.4s	remaining: 23.2s
# 199:	learn: 0.5117950	total: 15.4s	remaining: 23.2s
# 200:	learn: 0.5115251	total: 15.5s	remaining: 23.1s
# 201:	learn: 0.5112160	total: 15.6s	remaining: 23s
# 202:	learn: 0.5109500	total: 15.7s	remaining: 23s
# 203:	learn: 0.5107475	total: 15.8s	remaining: 22.9s
# 204:	learn: 0.5104036	total: 15.8s	remaining: 22.8s
# 205:	learn: 0.5101752	total: 15.9s	remaining: 22.7s
# 206:	learn: 0.5100295	total: 16s	remaining: 22.6s
# 207:	learn: 0.5097751	total: 16.1s	remaining: 22.5s
# 208:	learn: 0.5094782	total: 16.1s	remaining: 22.5s
# 209:	learn: 0.5094185	total: 16.2s	remaining: 22.4s
# 210:	learn: 0.5092486	total: 16.3s	remaining: 22.3s
# 211:	learn: 0.5089396	total: 16.4s	remaining: 22.2s
# 212:	learn: 0.5087458	total: 16.4s	remaining: 22.2s
# 213:	learn: 0.5084785	total: 16.5s	remaining: 22.1s
# 214:	learn: 0.5082868	total: 16.6s	remaining: 22s
# 215:	learn: 0.5079903	total: 16.7s	remaining: 22s
# 216:	learn: 0.5077788	total: 16.8s	remaining: 21.9s
# 217:	learn: 0.5077437	total: 16.9s	remaining: 21.8s
# 218:	learn: 0.5076007	total: 16.9s	remaining: 21.7s
# 219:	learn: 0.5073595	total: 17s	remaining: 21.7s
# 220:	learn: 0.5071173	total: 17.1s	remaining: 21.6s
# 221:	learn: 0.5069035	total: 17.2s	remaining: 21.5s
# 222:	learn: 0.5065386	total: 17.3s	remaining: 21.4s
# 223:	learn: 0.5062873	total: 17.3s	remaining: 21.4s
# 224:	learn: 0.5059524	total: 17.4s	remaining: 21.3s
# 225:	learn: 0.5057082	total: 17.5s	remaining: 21.2s
# 226:	learn: 0.5055856	total: 17.6s	remaining: 21.2s
# 227:	learn: 0.5054284	total: 17.7s	remaining: 21.1s
# 228:	learn: 0.5053411	total: 17.8s	remaining: 21s
# 229:	learn: 0.5052039	total: 17.9s	remaining: 21s
# 230:	learn: 0.5051247	total: 17.9s	remaining: 20.8s
# 231:	learn: 0.5047764	total: 18s	remaining: 20.8s
# 232:	learn: 0.5044885	total: 18.1s	remaining: 20.7s
# 233:	learn: 0.5042691	total: 18.2s	remaining: 20.6s
# 234:	learn: 0.5041206	total: 18.3s	remaining: 20.6s
# 235:	learn: 0.5039192	total: 18.3s	remaining: 20.5s
# 236:	learn: 0.5036957	total: 18.4s	remaining: 20.4s
# 237:	learn: 0.5036625	total: 18.4s	remaining: 20.3s
# 238:	learn: 0.5033231	total: 18.5s	remaining: 20.2s
# 239:	learn: 0.5031292	total: 18.6s	remaining: 20.2s
# 240:	learn: 0.5028284	total: 18.7s	remaining: 20.1s
# 241:	learn: 0.5027795	total: 18.8s	remaining: 20s
# 242:	learn: 0.5024852	total: 18.8s	remaining: 19.9s
# 243:	learn: 0.5023997	total: 18.9s	remaining: 19.9s
# 244:	learn: 0.5022899	total: 19s	remaining: 19.8s
# 245:	learn: 0.5022899	total: 19s	remaining: 19.7s
# 246:	learn: 0.5021327	total: 19.1s	remaining: 19.6s
# 247:	learn: 0.5019290	total: 19.2s	remaining: 19.5s
# 248:	learn: 0.5014480	total: 19.3s	remaining: 19.5s
# 249:	learn: 0.5012213	total: 19.4s	remaining: 19.4s
# 250:	learn: 0.5010338	total: 19.5s	remaining: 19.3s
# 251:	learn: 0.5008763	total: 19.6s	remaining: 19.3s
# 252:	learn: 0.5007572	total: 19.6s	remaining: 19.2s
# 253:	learn: 0.5006349	total: 19.7s	remaining: 19.1s
# 254:	learn: 0.5001421	total: 19.8s	remaining: 19s
# 255:	learn: 0.4998495	total: 19.9s	remaining: 19s
# 256:	learn: 0.4993701	total: 20s	remaining: 18.9s
# 257:	learn: 0.4992283	total: 20.1s	remaining: 18.8s
# 258:	learn: 0.4991413	total: 20.1s	remaining: 18.7s
# 259:	learn: 0.4989292	total: 20.2s	remaining: 18.7s
# 260:	learn: 0.4987818	total: 20.3s	remaining: 18.6s
# 261:	learn: 0.4986226	total: 20.4s	remaining: 18.5s
# 262:	learn: 0.4985342	total: 20.5s	remaining: 18.5s
# 263:	learn: 0.4985008	total: 20.5s	remaining: 18.4s
# 264:	learn: 0.4984878	total: 20.6s	remaining: 18.2s
# 265:	learn: 0.4983497	total: 20.7s	remaining: 18.2s
# 266:	learn: 0.4978253	total: 20.7s	remaining: 18.1s
# 267:	learn: 0.4976075	total: 20.8s	remaining: 18s
# 268:	learn: 0.4975022	total: 20.9s	remaining: 17.9s
# 269:	learn: 0.4973407	total: 21s	remaining: 17.9s
# 270:	learn: 0.4970269	total: 21s	remaining: 17.8s
# 271:	learn: 0.4966081	total: 21.1s	remaining: 17.7s
# 272:	learn: 0.4963737	total: 21.2s	remaining: 17.7s
# 273:	learn: 0.4962278	total: 21.3s	remaining: 17.6s
# 274:	learn: 0.4959493	total: 21.4s	remaining: 17.5s
# 275:	learn: 0.4957736	total: 21.5s	remaining: 17.4s
# 276:	learn: 0.4955826	total: 21.6s	remaining: 17.4s
# 277:	learn: 0.4953707	total: 21.7s	remaining: 17.3s
# 278:	learn: 0.4951795	total: 21.8s	remaining: 17.2s
# 279:	learn: 0.4950296	total: 21.8s	remaining: 17.2s
# 280:	learn: 0.4949991	total: 21.9s	remaining: 17.1s
# 281:	learn: 0.4948754	total: 22s	remaining: 17s
# 282:	learn: 0.4946965	total: 22.1s	remaining: 16.9s
# 283:	learn: 0.4945394	total: 22.1s	remaining: 16.8s
# 284:	learn: 0.4942807	total: 22.2s	remaining: 16.8s
# 285:	learn: 0.4940791	total: 22.3s	remaining: 16.7s
# 286:	learn: 0.4938877	total: 22.4s	remaining: 16.6s
# 287:	learn: 0.4937521	total: 22.5s	remaining: 16.5s
# 288:	learn: 0.4933847	total: 22.6s	remaining: 16.5s
# 289:	learn: 0.4931661	total: 22.7s	remaining: 16.4s
# 290:	learn: 0.4929231	total: 22.7s	remaining: 16.3s
# 291:	learn: 0.4927807	total: 22.8s	remaining: 16.3s
# 292:	learn: 0.4927330	total: 22.9s	remaining: 16.2s
# 293:	learn: 0.4925155	total: 23s	remaining: 16.1s
# 294:	learn: 0.4922932	total: 23s	remaining: 16s
# 295:	learn: 0.4919769	total: 23.1s	remaining: 15.9s
# 296:	learn: 0.4918300	total: 23.2s	remaining: 15.9s
# 297:	learn: 0.4918129	total: 23.3s	remaining: 15.8s
# 298:	learn: 0.4915966	total: 23.4s	remaining: 15.7s
# 299:	learn: 0.4914672	total: 23.4s	remaining: 15.6s
# 300:	learn: 0.4914527	total: 23.5s	remaining: 15.5s
# 301:	learn: 0.4913296	total: 23.6s	remaining: 15.5s
# 302:	learn: 0.4913195	total: 23.6s	remaining: 15.3s
# 303:	learn: 0.4911647	total: 23.7s	remaining: 15.3s
# 304:	learn: 0.4907702	total: 23.8s	remaining: 15.2s
# 305:	learn: 0.4906032	total: 23.9s	remaining: 15.1s
# 306:	learn: 0.4903286	total: 23.9s	remaining: 15s
# 307:	learn: 0.4902001	total: 24s	remaining: 15s
# 308:	learn: 0.4900882	total: 24.1s	remaining: 14.9s
# 309:	learn: 0.4899987	total: 24.2s	remaining: 14.8s
# 310:	learn: 0.4899144	total: 24.3s	remaining: 14.7s
# 311:	learn: 0.4898667	total: 24.3s	remaining: 14.7s
# 312:	learn: 0.4898180	total: 24.4s	remaining: 14.6s
# 313:	learn: 0.4896394	total: 24.5s	remaining: 14.5s
# 314:	learn: 0.4894972	total: 24.6s	remaining: 14.4s
# 315:	learn: 0.4893832	total: 24.6s	remaining: 14.3s
# 316:	learn: 0.4892278	total: 24.7s	remaining: 14.3s
# 317:	learn: 0.4892248	total: 24.8s	remaining: 14.2s
# 318:	learn: 0.4891534	total: 24.8s	remaining: 14.1s
# 319:	learn: 0.4889482	total: 24.9s	remaining: 14s
# 320:	learn: 0.4888094	total: 25s	remaining: 13.9s
# 321:	learn: 0.4886139	total: 25.1s	remaining: 13.9s
# 322:	learn: 0.4885260	total: 25.2s	remaining: 13.8s
# 323:	learn: 0.4885037	total: 25.2s	remaining: 13.7s
# 324:	learn: 0.4884641	total: 25.3s	remaining: 13.6s
# 325:	learn: 0.4883643	total: 25.3s	remaining: 13.5s
# 326:	learn: 0.4882767	total: 25.4s	remaining: 13.5s
# 327:	learn: 0.4880721	total: 25.5s	remaining: 13.4s
# 328:	learn: 0.4880372	total: 25.6s	remaining: 13.3s
# 329:	learn: 0.4880368	total: 25.6s	remaining: 13.2s
# 330:	learn: 0.4879106	total: 25.7s	remaining: 13.1s
# 331:	learn: 0.4875950	total: 25.8s	remaining: 13s
# 332:	learn: 0.4875066	total: 25.9s	remaining: 13s
# 333:	learn: 0.4874233	total: 26s	remaining: 12.9s
# 334:	learn: 0.4871976	total: 26s	remaining: 12.8s
# 335:	learn: 0.4869887	total: 26.1s	remaining: 12.8s
# 336:	learn: 0.4867926	total: 26.2s	remaining: 12.7s
# 337:	learn: 0.4867242	total: 26.3s	remaining: 12.6s
# 338:	learn: 0.4864738	total: 26.4s	remaining: 12.5s
# 339:	learn: 0.4862297	total: 26.5s	remaining: 12.5s
# 340:	learn: 0.4861352	total: 26.5s	remaining: 12.4s
# 341:	learn: 0.4858975	total: 26.6s	remaining: 12.3s
# 342:	learn: 0.4857332	total: 26.7s	remaining: 12.2s
# 343:	learn: 0.4856166	total: 26.8s	remaining: 12.1s
# 344:	learn: 0.4852579	total: 26.8s	remaining: 12.1s
# 345:	learn: 0.4851724	total: 26.9s	remaining: 12s
# 346:	learn: 0.4850938	total: 27s	remaining: 11.9s
# 347:	learn: 0.4849853	total: 27.1s	remaining: 11.8s
# 348:	learn: 0.4848370	total: 27.2s	remaining: 11.8s
# 349:	learn: 0.4845281	total: 27.3s	remaining: 11.7s
# 350:	learn: 0.4842965	total: 27.4s	remaining: 11.6s
# 351:	learn: 0.4842396	total: 27.4s	remaining: 11.5s
# 352:	learn: 0.4840881	total: 27.5s	remaining: 11.5s
# 353:	learn: 0.4840013	total: 27.6s	remaining: 11.4s
# 354:	learn: 0.4839085	total: 27.7s	remaining: 11.3s
# 355:	learn: 0.4837914	total: 27.8s	remaining: 11.2s
# 356:	learn: 0.4835622	total: 27.8s	remaining: 11.1s
# 357:	learn: 0.4834725	total: 27.9s	remaining: 11.1s
# 358:	learn: 0.4832486	total: 28s	remaining: 11s
# 359:	learn: 0.4830573	total: 28.1s	remaining: 10.9s
# 360:	learn: 0.4829039	total: 28.1s	remaining: 10.8s
# 361:	learn: 0.4825453	total: 28.2s	remaining: 10.8s
# 362:	learn: 0.4824185	total: 28.3s	remaining: 10.7s
# 363:	learn: 0.4822768	total: 28.4s	remaining: 10.6s
# 364:	learn: 0.4821513	total: 28.5s	remaining: 10.5s
# 365:	learn: 0.4820990	total: 28.5s	remaining: 10.4s
# 366:	learn: 0.4820206	total: 28.6s	remaining: 10.4s
# 367:	learn: 0.4819486	total: 28.7s	remaining: 10.3s
# 368:	learn: 0.4818686	total: 28.8s	remaining: 10.2s
# 369:	learn: 0.4816223	total: 28.9s	remaining: 10.1s
# 370:	learn: 0.4813491	total: 28.9s	remaining: 10.1s
# 371:	learn: 0.4812419	total: 29s	remaining: 9.98s
# 372:	learn: 0.4811641	total: 29.1s	remaining: 9.91s
# 373:	learn: 0.4809751	total: 29.2s	remaining: 9.83s
# 374:	learn: 0.4808246	total: 29.3s	remaining: 9.75s
# 375:	learn: 0.4807054	total: 29.3s	remaining: 9.68s
# 376:	learn: 0.4805275	total: 29.4s	remaining: 9.6s
# 377:	learn: 0.4804107	total: 29.5s	remaining: 9.52s
# 378:	learn: 0.4803963	total: 29.6s	remaining: 9.44s
# 379:	learn: 0.4803425	total: 29.6s	remaining: 9.36s
# 380:	learn: 0.4802164	total: 29.7s	remaining: 9.28s
# 381:	learn: 0.4800755	total: 29.8s	remaining: 9.21s
# 382:	learn: 0.4800561	total: 29.9s	remaining: 9.12s
# 383:	learn: 0.4798893	total: 29.9s	remaining: 9.05s
# 384:	learn: 0.4797725	total: 30s	remaining: 8.96s
# 385:	learn: 0.4795030	total: 30.1s	remaining: 8.89s
# 386:	learn: 0.4795013	total: 30.1s	remaining: 8.8s
# 387:	learn: 0.4794289	total: 30.2s	remaining: 8.72s
# 388:	learn: 0.4791903	total: 30.3s	remaining: 8.64s
# 389:	learn: 0.4789030	total: 30.4s	remaining: 8.57s
# 390:	learn: 0.4788975	total: 30.4s	remaining: 8.49s
# 391:	learn: 0.4787009	total: 30.5s	remaining: 8.41s
# 392:	learn: 0.4785140	total: 30.6s	remaining: 8.34s
# 393:	learn: 0.4782371	total: 30.7s	remaining: 8.26s
# 394:	learn: 0.4780950	total: 30.8s	remaining: 8.18s
# 395:	learn: 0.4776889	total: 30.9s	remaining: 8.1s
# 396:	learn: 0.4775661	total: 30.9s	remaining: 8.02s
# 397:	learn: 0.4773654	total: 31s	remaining: 7.95s
# 398:	learn: 0.4771791	total: 31.1s	remaining: 7.87s
# 399:	learn: 0.4768943	total: 31.2s	remaining: 7.79s
# 400:	learn: 0.4767295	total: 31.2s	remaining: 7.71s
# 401:	learn: 0.4765101	total: 31.3s	remaining: 7.64s
# 402:	learn: 0.4763340	total: 31.4s	remaining: 7.56s
# 403:	learn: 0.4759602	total: 31.5s	remaining: 7.48s
# 404:	learn: 0.4758279	total: 31.6s	remaining: 7.4s
# 405:	learn: 0.4757429	total: 31.6s	remaining: 7.33s
# 406:	learn: 0.4756115	total: 31.7s	remaining: 7.25s
# 407:	learn: 0.4755107	total: 31.8s	remaining: 7.17s
# 408:	learn: 0.4753743	total: 31.9s	remaining: 7.09s
# 409:	learn: 0.4752962	total: 32s	remaining: 7.02s
# 410:	learn: 0.4751354	total: 32s	remaining: 6.94s
# 411:	learn: 0.4751305	total: 32.1s	remaining: 6.85s
# 412:	learn: 0.4750999	total: 32.2s	remaining: 6.77s
# 413:	learn: 0.4749924	total: 32.2s	remaining: 6.7s
# 414:	learn: 0.4749206	total: 32.3s	remaining: 6.62s
# 415:	learn: 0.4748845	total: 32.4s	remaining: 6.54s
# 416:	learn: 0.4747673	total: 32.5s	remaining: 6.46s
# 417:	learn: 0.4745691	total: 32.5s	remaining: 6.38s
# 418:	learn: 0.4744384	total: 32.6s	remaining: 6.3s
# 419:	learn: 0.4744253	total: 32.7s	remaining: 6.22s
# 420:	learn: 0.4743936	total: 32.7s	remaining: 6.14s
# 421:	learn: 0.4743167	total: 32.8s	remaining: 6.07s
# 422:	learn: 0.4741577	total: 32.9s	remaining: 5.99s
# 423:	learn: 0.4739914	total: 33s	remaining: 5.91s
# 424:	learn: 0.4739449	total: 33.1s	remaining: 5.84s
# 425:	learn: 0.4738942	total: 33.1s	remaining: 5.75s
# 426:	learn: 0.4737676	total: 33.2s	remaining: 5.67s
# 427:	learn: 0.4737490	total: 33.3s	remaining: 5.6s
# 428:	learn: 0.4736035	total: 33.4s	remaining: 5.52s
# 429:	learn: 0.4734722	total: 33.5s	remaining: 5.45s
# 430:	learn: 0.4734689	total: 33.5s	remaining: 5.37s
# 431:	learn: 0.4732587	total: 33.6s	remaining: 5.29s
# 432:	learn: 0.4730341	total: 33.7s	remaining: 5.21s
# 433:	learn: 0.4728701	total: 33.8s	remaining: 5.13s
# 434:	learn: 0.4727695	total: 33.8s	remaining: 5.06s
# 435:	learn: 0.4726182	total: 33.9s	remaining: 4.98s
# 436:	learn: 0.4725193	total: 34s	remaining: 4.9s
# 437:	learn: 0.4724293	total: 34.1s	remaining: 4.83s
# 438:	learn: 0.4723672	total: 34.2s	remaining: 4.75s
# 439:	learn: 0.4722534	total: 34.3s	remaining: 4.67s
# 440:	learn: 0.4721997	total: 34.3s	remaining: 4.59s
# 441:	learn: 0.4720872	total: 34.4s	remaining: 4.52s
# 442:	learn: 0.4719676	total: 34.5s	remaining: 4.44s
# 443:	learn: 0.4719079	total: 34.6s	remaining: 4.36s
# 444:	learn: 0.4716472	total: 34.7s	remaining: 4.29s
# 445:	learn: 0.4714669	total: 34.8s	remaining: 4.21s
# 446:	learn: 0.4713846	total: 34.9s	remaining: 4.13s
# 447:	learn: 0.4712303	total: 34.9s	remaining: 4.06s
# 448:	learn: 0.4711863	total: 35s	remaining: 3.98s
# 449:	learn: 0.4709832	total: 35.1s	remaining: 3.9s
# 450:	learn: 0.4709182	total: 35.2s	remaining: 3.82s
# 451:	learn: 0.4706204	total: 35.3s	remaining: 3.75s
# 452:	learn: 0.4704473	total: 35.4s	remaining: 3.67s
# 453:	learn: 0.4701993	total: 35.4s	remaining: 3.59s
# 454:	learn: 0.4700879	total: 35.5s	remaining: 3.51s
# 455:	learn: 0.4698971	total: 35.6s	remaining: 3.44s
# 456:	learn: 0.4697687	total: 35.7s	remaining: 3.36s
# 457:	learn: 0.4697332	total: 35.7s	remaining: 3.28s
# 458:	learn: 0.4696196	total: 35.8s	remaining: 3.2s
# 459:	learn: 0.4693416	total: 35.9s	remaining: 3.12s
# 460:	learn: 0.4692437	total: 36s	remaining: 3.04s
# 461:	learn: 0.4691384	total: 36.1s	remaining: 2.97s
# 462:	learn: 0.4687801	total: 36.2s	remaining: 2.89s
# 463:	learn: 0.4686457	total: 36.2s	remaining: 2.81s
# 464:	learn: 0.4684992	total: 36.3s	remaining: 2.73s
# 465:	learn: 0.4681473	total: 36.4s	remaining: 2.66s
# 466:	learn: 0.4680655	total: 36.5s	remaining: 2.58s
# 467:	learn: 0.4679981	total: 36.6s	remaining: 2.5s
# 468:	learn: 0.4678563	total: 36.6s	remaining: 2.42s
# 469:	learn: 0.4677523	total: 36.7s	remaining: 2.34s
# 470:	learn: 0.4676147	total: 36.8s	remaining: 2.27s
# 471:	learn: 0.4674843	total: 36.9s	remaining: 2.19s
# 472:	learn: 0.4673257	total: 37s	remaining: 2.11s
# 473:	learn: 0.4671458	total: 37s	remaining: 2.03s
# 474:	learn: 0.4669865	total: 37.1s	remaining: 1.95s
# 475:	learn: 0.4669127	total: 37.2s	remaining: 1.88s
# 476:	learn: 0.4668491	total: 37.3s	remaining: 1.8s
# 477:	learn: 0.4667389	total: 37.4s	remaining: 1.72s
# 478:	learn: 0.4665822	total: 37.4s	remaining: 1.64s
# 479:	learn: 0.4664988	total: 37.5s	remaining: 1.56s
# 480:	learn: 0.4664009	total: 37.6s	remaining: 1.49s
# 481:	learn: 0.4662023	total: 37.7s	remaining: 1.41s
# 482:	learn: 0.4659606	total: 37.8s	remaining: 1.33s
# 483:	learn: 0.4659227	total: 37.9s	remaining: 1.25s
# 484:	learn: 0.4657402	total: 38s	remaining: 1.17s
# 485:	learn: 0.4655449	total: 38s	remaining: 1.09s
# 486:	learn: 0.4654172	total: 38.1s	remaining: 1.02s
# 487:	learn: 0.4653981	total: 38.2s	remaining: 940ms
# 488:	learn: 0.4651973	total: 38.3s	remaining: 861ms
# 489:	learn: 0.4650189	total: 38.4s	remaining: 783ms
# 490:	learn: 0.4647881	total: 38.5s	remaining: 705ms
# 491:	learn: 0.4645896	total: 38.6s	remaining: 627ms
# 492:	learn: 0.4644791	total: 38.6s	remaining: 549ms
# 493:	learn: 0.4643760	total: 38.7s	remaining: 470ms
# 494:	learn: 0.4641395	total: 38.8s	remaining: 392ms
# 495:	learn: 0.4640223	total: 38.9s	remaining: 314ms
# 496:	learn: 0.4636208	total: 39s	remaining: 235ms
# 497:	learn: 0.4634896	total: 39.1s	remaining: 157ms
# 498:	learn: 0.4633464	total: 39.2s	remaining: 78.5ms
# 499:	learn: 0.4631357	total: 39.2s	remaining: 0us

# %%
np.sum(cb_model.predict(valid) == target_valid)
# Out:
# 679

# %%
def process_group(name, test_group):
    num_feat_train = []
    cat_feat_train = []
    target_train = []
    
    test_group_history = test_group.iloc[:math.floor(test_group['session_position'].size / 2)].rename(index=str, columns={"track_id_clean": "track_id"})
    test_group_predict_all = test_group.iloc[math.floor(test_group['session_position'].size / 2):].rename(index=str, columns={"track_id_clean": "track_id"})
    test_group_predict = test_group_predict_all.iloc[:,:4]
    test_group_predict['logits'] = test_group_predict_all['logits']
    test_group_target = test_group_predict_all.iloc[:, 5].astype(int)

    target_train.extend(test_group_target.tolist())

    # first get the summarization data
    num_feat_hist, cat_feat_hist = get_session_history_summarization(test_group_history)

    # use the append of two piecese because of the structure of test set
    all_track_ids = test_group_history['track_id'].append(test_group_predict['track_id'])

    # used to fill in 0s if it's the last song in the current history since it don't have after tracks
    num_feat_after_sum_len = 51
    cat_feat_after_sum_len = 4

    isLast = False
    for index, row in test_group_predict.iterrows():
        num_feat_predict_row = []
        cat_feat_predict_row = []

        num_feat_predict_row.extend(num_feat_hist)
        cat_feat_predict_row.extend(cat_feat_hist)

        # add categorical variable session_position (session length is already included in cat_feat_hist)
        session_position = row[1]
        cat_feat_predict_row.append(session_position)

        # use the append of two piecese because of the structure of test set
        entire_track_id = test_group_history['track_id'].append(test_group_predict['track_id'])

        before_tracks = all_track_ids[:(session_position - 1)]
        current_track = all_track_ids[(session_position - 1)]
        after_tracks = all_track_ids[(session_position):]
        if (len(after_tracks) == 0):
            isLast = True

        # count of how many times this item have appeared before and after current track
        before_count = (before_tracks == current_track).sum() / len(before_tracks)
        before_proportion = before_count / len(before_tracks)
        if isLast:
            after_count = 0
            after_proportion = 0
        else:
            after_count = (after_tracks == current_track).sum() / len(after_tracks)
            after_proportion = after_count / len(after_tracks)
        num_feat_predict_row.extend([after_count, after_proportion, before_count, before_proportion])

        # get the three corresponding dataframes
        current_track_df = get_track_df(current_track)
        before_tracks_df = get_track_df(before_tracks)
        after_tracks_df = get_track_df(after_tracks)

        # get current track data
        num_feat_current, cat_feat_current = get_current_track_feature(current_track_df)
        num_feat_predict_row.extend(num_feat_current)
        cat_feat_predict_row.extend(cat_feat_current)

        # get before tracks summarization data
        num_feat_before_sum, cat_feat_before_sum = get_tracks_df_summarization_feature(before_tracks_df)
        num_feat_predict_row.extend(num_feat_before_sum)
        cat_feat_predict_row.extend(cat_feat_before_sum)

        # get after tracks summarizaiton data
        if isLast:
            num_feat_after_sum = [0] * num_feat_after_sum_len
            cat_feat_after_sum = ['last'] * cat_feat_after_sum_len
        else:
            num_feat_after_sum, cat_feat_after_sum = get_tracks_df_summarization_feature(after_tracks_df)

        num_feat_predict_row.extend(num_feat_after_sum)
        cat_feat_predict_row.extend(cat_feat_after_sum)

        # add numerical feature logits
        logit = row[4]
        num_feat_predict_row.append(logit)

        num_feat_train.append(num_feat_predict_row)
        cat_feat_train.append(cat_feat_predict_row)
        
    return {
        'name': name,
        'num_feat_train': num_feat_train,
        'cat_feat_train': cat_feat_train,
        'target_train': target_train
    }

# %%
import multiprocessing

pool = multiprocessing.Pool(processes=32)

# %%
result = pool.map(process_group, catboost_train_raw_group)

# %%
pool.close()
pool.join()
